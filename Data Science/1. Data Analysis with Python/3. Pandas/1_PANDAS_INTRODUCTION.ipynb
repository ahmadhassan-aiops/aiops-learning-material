# %% [markdown]
# ##Pupose of Pandas Library

# %% [markdown]
# - pandas is a software library written for the Python programming language for **data manipulation and analysis**
#
# - In particular, it offers data structures and operations for manipulating **numerical tables and time series**.

# %% [markdown]
# ##DATA STRUTURES OF PANDAS
# - 1.DATAFRAMES(i.e a whole table)
# - 2.SERIES(i.e a row or column of table)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##HOW TO IMPORT DATA INTO PYTHON USING PANDAS?

# %%
# # Import the necessary module.
# from google.colab import drive

# # Mount Google Drive.
# drive.mount('/content/drive')

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CLIENTS/7. Dammy/Pandas/Fortune 500 2017 - Fortune 500.csv')

# %% [markdown]
# #Important functions and attributes

# %% [markdown]
# ##1.HEAD/TAIL/SAMPLE

# %%
# # To visualize the hidden column in a data frame
# pd.set_option('display.max_columns',None)

# # To visualize the hidden column in a data frame
# pd.set_option('display.max_rows',None)

# %%
# by defauly head gives only first 5 rows
df.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
# ...

# %%
# by defauly tail gives only last 5 rows
df.tail(3)
# Out:
#      Rank           Title                      Website  Employees  \
# 497   498           Yahoo         http://www.yahoo.com       8500
# 498   499   Vistra Energy  http://www.vistraenergy.com       4431
# 499   500  ABM Industries           http://www.abm.com     110000
#
#                 Sector                          Industry     Hqlocation  \
# 497         Technology   Internet Services and Retailing  Sunnyvale, CA
# 498             Energy                            Energy     Dallas, TX
# 499  Business Services  Diversified Outsourcing Services   New York, NY
#
#               Hqaddr     Hqcity Hqstate  Hqzip         Hqtel  \
# 497   701 First Ave.  Sunnyvale      CA  94089  408-349-3300
# 498   1601 Bryan St.     Dallas      TX  75201  214-812-4600
# 499  1 Liberty Plaza   New York      NY  10006  212-297-0200
#
#                   Ceo                                      Ceo-title  \
# 497  Marissa A. Mayer  President, Chief Executive Officer & Director
# ...

# %%
# It gives us random rows from the dataframe
df.sample(5)
# Out:
#      Rank                           Title                       Website  \
# 162   163          Marriott International       http://www.marriott.com
# 53     54                          Pfizer         http://www.pfizer.com
# 74     75  Liberty Mutual Insurance Group  http://www.libertymutual.com
# 352   353                      PulteGroup  http://www.pultegroupinc.com
# 189   190                        WestRock       http://www.westrock.com
#
#      Employees                         Sector  \
# 162     226500  Hotels, Restaurants & Leisure
# 53       96500                    Health Care
# 74       50000                     Financials
# 352       4623     Engineering & Construction
# 189      39000                      Materials
#
#                                      Industry    Hqlocation  \
# 162                  Hotels, Casinos, Resorts  Bethesda, MD
# 53                            Pharmaceuticals  New York, NY
# 74   Insurance: Property and Casualty (Stock)    Boston, MA
# ...

# %% [markdown]
# ##2.shape(attribute)

# %%
df.shape
# Out:
# (500, 23)

# %% [markdown]
# ##3.info
#
# - object in most of the times is string type of data but can be of other types
# - memory usage is important parameter as it should be as minimum as possible.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         500 non-null    int64
#  1   Title        500 non-null    object
#  2   Website      500 non-null    object
#  3   Employees    500 non-null    int64
#  4   Sector       500 non-null    object
#  5   Industry     500 non-null    object
#  6   Hqlocation   500 non-null    object
#  7   Hqaddr       500 non-null    object
#  8   Hqcity       500 non-null    object
#  9   Hqstate      500 non-null    object
#  10  Hqzip        500 non-null    int64
#  11  Hqtel        500 non-null    object
#  12  Ceo          500 non-null    object
#  13  Ceo-title    500 non-null    object
#  14  Address      500 non-null    object
#  15  Ticker       500 non-null    object
#  16  Fullname     500 non-null    object
#  17  Revenues     500 non-null    int64
# ...

# %% [markdown]
# ##4.describe
#
# - It works only on **numerical values**

# %%
# it will give us the summary statistics
df.describe()
# Out:
#              Rank     Employees         Hqzip       Revenues  Revchange  \
# count  500.000000  5.000000e+02    500.000000     500.000000  500.00000
# mean   250.492000  5.635013e+04  46791.714000   24111.748000    3.75800
# std    144.477366  1.234520e+05  30160.384765   38337.353337   19.96748
# min      1.000000  8.300000e+01   1104.000000    5145.000000  -57.50000
# 25%    125.750000  1.190000e+04  19099.000000    7245.000000   -3.82500
# 50%    250.500000  2.500000e+04  46244.500000   11384.000000    1.90000
# 75%    375.250000  5.682525e+04  75045.000000   22605.250000    7.32500
# max    500.000000  2.300000e+06  98188.000000  485873.000000  197.30000
#
#             Profits        Assets  Totshequity
# count    500.000000  5.000000e+02     500.0000
# mean    1779.479800  8.038934e+04   13640.1470
# std     3937.558721  2.704257e+05   30523.1538
# min    -6177.000000  4.370000e+02  -12688.0000
# 25%      235.725000  8.436500e+03    1997.5000
# ...

# %% [markdown]
# ##5.Isnull()

# %%
df.isnull().sum()/len(df)*100
# Out:
# Rank           0.0
# Title          0.0
# Website        0.0
# Employees      0.0
# Sector         0.0
# Industry       0.0
# Hqlocation     0.0
# Hqaddr         0.0
# Hqcity         0.0
# Hqstate        0.0
# Hqzip          0.0
# Hqtel          0.0
# Ceo            0.0
# Ceo-title      0.0
# Address        0.0
# Ticker         0.0
# Fullname       0.0
# Revenues       0.0
# Revchange      0.0
# Profits        0.0
# Prftchange     0.0
# Assets         0.0
# Totshequity    0.0
# dtype: float64
