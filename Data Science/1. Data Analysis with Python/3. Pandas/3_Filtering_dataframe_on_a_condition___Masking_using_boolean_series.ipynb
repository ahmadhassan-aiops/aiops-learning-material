# %%
import numpy as np
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CLIENTS/7. Dammy/Pandas/Fortune 500 2017 - Fortune 500.csv')

# Set display options to show maximum columns
pd.set_option('display.max_columns', None)

# %%
data.sample(5)
# Out:
#      Rank                            Title                          Website  \
# 453   454               Genesis Healthcare        http://www.genesishcc.com
# 71     72                         Best Buy           http://www.bestbuy.com
# 385   386  Harman International Industries            http://www.harman.com
# 414   415                CalAtlantic Group  http://www.calatlantichomes.com
# 326   327                Boston Scientific  http://www.bostonscientific.com
#
#      Employees                      Sector                           Industry  \
# 453      82000                 Health Care    Health Care: Medical Facilities
# 71      125000                   Retailing         Specialty Retailers: Other
# 385      26000                 Industrials  Electronics, Electrical Equipment
# 414       3055  Engineering & Construction                       Homebuilders
# 326      27000                 Health Care     Medical Products and Equipment
#
# ...

# %% [markdown]
# #simple conditional fetching

# %% [markdown]
# ##Q#1.Filter the companies and thier respective number where the Sector is 'Retailing'.

# %%
data[data['Sector']=='Retailing']
# Out:
#      Rank                     Title                            Website  \
# 0       1                   Walmart             http://www.walmart.com
# 15     16                    Costco              http://www.costco.com
# 22     23                Home Depot           http://www.homedepot.com
# 37     38                    Target              http://www.target.com
# 39     40                    Lowe’s               http://www.lowes.com
# 71     72                  Best Buy             http://www.bestbuy.com
# 86     87                       TJX                 http://www.tjx.com
# 109   110                    Macy’s            http://www.macysinc.com
# 126   127            Sears Holdings       http://www.searsholdings.com
# 127   128            Dollar General       http://www.dollargeneral.com
# 128   129                AutoNation          http://www.autonation.com
# 135   136               Dollar Tree          http://www.dollartree.com
# ...

# %%
data[data['Sector']=='Retailing'].shape[0]
# Out:
# 47

# %% [markdown]
# ##Q#2.Filter the companies where the company is based in the state of 'CA' (California). Also find out the respective numbers of companies listed in CA!

# %%
data[data['Hqstate'] == 'CA']
# Out:
#      Rank                       Title                                 Website  \
# 2       3                       Apple                    http://www.apple.com
# 4       5                    McKesson                 http://www.mckesson.com
# 18     19                     Chevron                  http://www.chevron.com
# 24     25                 Wells Fargo               http://www.wellsfargo.com
# 26     27                    Alphabet                      http://www.abc.xyz
# 46     47                       Intel                    http://www.intel.com
# 51     52                      Disney                   http://www.disney.com
# 58     59  Hewlett Packard Enterprise                      http://www.hpe.com
# 59     60               Cisco Systems                    http://www.cisco.com
# 60     61                          HP                       http://www.hp.com
# 80     81                      Oracle                   http://www.oracle.com
# ...

# %%
data[data['Hqstate'] == 'CA'].shape[0]
# Out:
# 53

# %% [markdown]
# #Complex conditional fetching

# %% [markdown]
# ##Q#1.Filter the companies where Revenues are greater than 150000 and employees are greater than 20 thousand'.

# %%
data[(data['Revenues'] > 150000) & (data['Employees'] > 20000)]
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# ...

# %%
data[(data['Revenues'] > 150000) & (data['Employees'] > 20000)].shape[0]
# Out:
# 10

# %% [markdown]
# ##Q#2.Filter the companies where Employees are more than 100000 and Profits are greater than 10000.

# %%
data[(data['Profits'] > 10000) & (data['Employees'] > 100000)]
# Out:
#     Rank                  Title                           Website  Employees  \
# 0      1                Walmart            http://www.walmart.com    2300000
# 1      2     Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2      3                  Apple              http://www.apple.com     116000
# 8      9                   AT&T                http://www.att.com     268540
# 13    14                Verizon            http://www.verizon.com     160900
# 20    21      J.P. Morgan Chase      http://www.jpmorganchase.com     243355
# 24    25            Wells Fargo         http://www.wellsfargo.com     269100
# 25    26  Bank of America Corp.      http://www.bankofamerica.com     208024
# 27    28              Microsoft          http://www.microsoft.com     114000
# 29    30              Citigroup          http://www.citigroup.com     219000
# 31    32                    IBM                http://www.ibm.com     414400
# ...

# %%
data[(data['Profits'] > 10000) & (data['Employees'] > 100000)].shape[0]
# Out:
# 14
