# %% [markdown]
# - This is always applied on series and mostly used on categorical data set.

# %%
import numpy as np
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CLIENTS/7. Dammy/Pandas/Fortune 500 2017 - Fortune 500.csv')

# Set display options to show maximum columns
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
# ...

# %% [markdown]
# ##Q#1.How many unique sectors are represented in the dataset? And calculate the frequency of each sector as well!

# %%
# To print out the total unique values in a particular feature
data['Sector'].nunique()
# Out:
# 21

# %%
# To print out the unique values names in a particular feature
data['Sector'].unique()
# Out:
# array(['Retailing', 'Financials', 'Technology', 'Energy', 'Wholesalers',
#        'Health Care', 'Motor Vehicles & Parts', 'Telecommunications',
#        'Industrials', 'Food & Drug Stores', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Apparel',
#        'Hotels, Restaurants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
data['Sector'].value_counts()
# Out:
# Sector
# Financials                       84
# Energy                           57
# Retailing                        47
# Technology                       43
# Health Care                      38
# Wholesalers                      29
# Food, Beverages & Tobacco        24
# Business Services                20
# Industrials                      19
# Materials                        19
# Transportation                   17
# Chemicals                        14
# Engineering & Construction       13
# Aerospace & Defense              12
# Household Products               12
# Media                            11
# Telecommunications               10
# Hotels, Restaurants & Leisure    10
# Motor Vehicles & Parts            9
# Food & Drug Stores                7
# Apparel                           5
# Name: count, dtype: int64

# %% [markdown]
# ##Q#2.who is the CEO with the highest occurrence?

# %%
data['Ceo'].value_counts()
# Out:
# Ceo
# Gregory B. Maffei        2
# John J. Christmann IV    2
# Miles D. White           2
# Gregory J. Goff          2
# Thomas J. McInerney      1
#                         ..
# Glen F. Post III         1
# N. Thomas Linebarger     1
# Mark Gross               1
# Geisha J. Williams       1
# Thomas J. Nimbley        1
# Name: count, Length: 496, dtype: int64

# %% [markdown]
# ##Q#3.How many unique industries are represented in the dataset? And find out 10 most frequent industries!

# %%
data['Industry'].value_counts().head(10)
# Out:
# Industry
# Utilities: Gas and Electric                 22
# Specialty Retailers: Other                  21
# Insurance: Property and Casualty (Stock)    20
# Commercial Banks                            19
# Chemicals                                   14
# Food Consumer Products                      13
# Aerospace and Defense                       12
# Diversified Financials                      12
# Wholesalers: Diversified                    10
# Telecommunications                          10
# Name: count, dtype: int64

# %% [markdown]
# ##Q#3.How many unique industries are represented in the dataset? And find out 10 least frequent industries!

# %%
data['Industry'].value_counts().tail(10)
# Out:
# Industry
# Trucking, Truck Leasing                           2
# Publishing, Printing                              2
# Scientific, Photographic and Control Equipment    2
# Advertising, Marketing                            2
# Building Materials, Glass                         2
# Mail, Package, and Freight Delivery               2
# Waste Management                                  2
# Forest and Paper Products                         1
# Transportation Equipment                          1
# Toys, Sporting Goods                              1
# Name: count, dtype: int64
