# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CLIENTS/7. Dammy/Pandas/Fortune 500 2017 - Fortune 500.csv')
df.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #FETCHING OF COLUMN

# %% [markdown]
# ##1.Fetching 1 column

# %%
#fething 1 column
df['Employees']
# Out:
# 0      2300000
# 1       367700
# 2       116000
# 3        72700
# 4        68000
#         ...
# 495      31000
# 496       4200
# 497       8500
# 498       4431
# 499     110000
# Name: Employees, Length: 500, dtype: int64

# %%
df.iloc[:,3]
# Out:
# 0      2300000
# 1       367700
# 2       116000
# 3        72700
# 4        68000
#         ...
# 495      31000
# 496       4200
# 497       8500
# 498       4431
# 499     110000
# Name: Employees, Length: 500, dtype: int64

# %% [markdown]
# ##1.Fetching multiple columns

# %%
df[['Title','Employees']]
# Out:
#                   Title  Employees
# 0               Walmart    2300000
# 1    Berkshire Hathaway     367700
# 2                 Apple     116000
# 3           Exxon Mobil      72700
# 4              McKesson      68000
# ..                  ...        ...
# 495       Michaels Cos.      31000
# 496       Toll Brothers       4200
# 497               Yahoo       8500
# 498       Vistra Energy       4431
# 499      ABM Industries     110000
#
# [500 rows x 2 columns]

# %%
df.iloc[30:45,[1,3]]
# Out:
#                         Title  Employees
# 30                    Comcast     159000
# 31                        IBM     414400
# 32  State Farm Insurance Cos.      68234
# 33                Phillips 66      14800
# 34          Johnson & Johnson     126400
# 35           Procter & Gamble     105000
# 36              Valero Energy       9996
# 37                     Target     323000
# 38                Freddie Mac       5982
# 39                     Lowe’s     240000
# 40          Dell Technologies     138000
# 41                    MetLife      58000
# 42                      Aetna      49500
# 43                    PepsiCo     264000
# 44     Archer Daniels Midland      31800

# %% [markdown]
# ---

# %% [markdown]
# #FETCHING OF ROW
#
# - For fetching rows we have to rely on iloc function only!

# %% [markdown]
# ##Fetch 1 row

# %%
df.iloc[400]
# Out:
# Rank                                                     401
# Title                                         Owens-Illinois
# Website                                   http://www.o-i.com
# Employees                                              27000
# Sector                                             Materials
# Industry                               Packaging, Containers
# Hqlocation                                    Perrysburg, OH
# Hqaddr                                   1 Michael Owens Way
# Hqcity                                            Perrysburg
# Hqstate                                                   OH
# Hqzip                                                  43551
# Hqtel                                           567-336-5000
# Ceo                                          Andres A. Lopez
# Ceo-title      President, Chief Executive Officer & Director
# Address            1 Michael Owens Way, Perrysburg, OH 43551
# ...

# %%
df.iloc[400:450:5]
# Out:
#      Rank                     Title                              Website  \
# 400   401            Owens-Illinois                   http://www.o-i.com
# 405   406       Activision Blizzard    http://www.activisionblizzard.com
# 410   411  American Financial Group                http://www.afginc.com
# 415   416   Dr Pepper Snapple Group  http://www.drpeppersnapplegroup.com
# 420   421      Builders FirstSource                  http://www.bldr.com
# 425   426               iHeartMedia           http://www.iheartmedia.com
# 430   431                    Ameren                http://www.ameren.com
# 435   436         Regions Financial               http://www.regions.com
# 440   441          AK Steel Holding               http://www.aksteel.com
# 445   446                       NVR                http://www.nvrinc.com
#
#      Employees                      Sector  \
# 400      27000                   Materials
# 405       9500                  Technology
# ...

# %% [markdown]
# ##Fetch multiple rows
